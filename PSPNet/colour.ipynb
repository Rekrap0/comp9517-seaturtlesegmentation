# %%
import os
import numpy as np
from pycocotools.coco import COCO
from PIL import Image
import matplotlib.pyplot as plt

plt.switch_backend('Agg')

coco = COCO('../data/annotations.json')

img_dir = '../data/'
mask_dir = '../data/mask'
os.makedirs(mask_dir, exist_ok=True)

category_color_map = {
    "turtle": (0, 0, 255),  # 蓝色
    "flipper": (0, 255, 0), # 绿色
    "head": (255, 0, 0)     # 红色
}


for image_id in coco.imgs.keys():
    img = coco.imgs[image_id]
    image_file = img['file_name']
    image_path = os.path.join(img_dir, image_file)
    
    if not os.path.exists(image_path):
        print(f"not found: {image_path}")
        continue
        

    cat_ids = coco.getCatIds()
    anns_ids = coco.getAnnIds(imgIds=img['id'], catIds=cat_ids, iscrowd=None)
    anns = coco.loadAnns(anns_ids)

    mask = np.zeros((img['height'], img['width'], 3), dtype=np.uint8)  # 创建一个三通道掩码
    
    for ann in anns:
        category_name = coco.loadCats(ann['category_id'])[0]['name']
        color_value = category_color_map.get(category_name, (0, 0, 0))  # 获取 RGB 颜色
        mask += np.dstack([coco.annToMask(ann) * color for color in color_value])
    masked_image_path = os.path.join(mask_dir, f"colored_mask_{image_file}")
    os.makedirs(os.path.dirname(masked_image_path), exist_ok=True)

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.axis('off')
    ax.imshow(mask, cmap='nipy_spectral')  
    fig.savefig(masked_image_path, bbox_inches='tight', pad_inches=0)
    plt.close(fig) 
    print(f"saving: {masked_image_path}")
# Out:
# loading annotations into memory...
# Done (t=3.79s)
# creating index...
# index created!
# saving: ../data/mask\colored_mask_images/t001/CAluWEgwPX.JPG
# saving: ../data/mask\colored_mask_images/t001/EKyrFKHQzh.JPG
# saving: ../data/mask\colored_mask_images/t001/ELAvEqeXxT.JPG
# saving: ../data/mask\colored_mask_images/t001/IxRLFwTGCv.JPG
# saving: ../data/mask\colored_mask_images/t001/LKCJAhfLBJ.JPG
# saving: ../data/mask\colored_mask_images/t001/LZystXlIqe.JPG
# saving: ../data/mask\colored_mask_images/t001/OiaMESWPyh.JPG
# saving: ../data/mask\colored_mask_images/t001/VMyJozldvy.jpg
# saving: ../data/mask\colored_mask_images/t001/XhbkFIOvZr.JPG
# saving: ../data/mask\colored_mask_images/t001/ZKnMahXQgJ.JPG
# saving: ../data/mask\colored_mask_images/t001/ZkWKNtWbVK.JPG
# saving: ../data/mask\colored_mask_images/t001/anuJvqUqBB.JPG
# saving: ../data/mask\colored_mask_images/t001/dLFculJDGP.JPG
# saving: ../data/mask\colored_mask_images/t001/iiWUAXGTRk.JPG
# saving: ../data/mask\colored_mask_images/t001/kTIpheVAuj.JPG
# saving: ../data/mask\colored_mask_images/t001/oYBbBMeIrc.JPG
# saving: ../data/mask\colored_mask_images/t001/rArWeMiEhi.JPG
# saving: ../data/mask\colored_mask_images/t001/tIpzeVcJbR.JPG
# saving: ../data/mask\colored_mask_images/t001/txgBopXzbZ.jpg
# saving: ../data/mask\colored_mask_images/t001/uUVqsYByEj.JPG
# saving: ../data/mask\colored_mask_images/t001/xldQLnWiRI.JPG
# saving: ../data/mask\colored_mask_images/t001/zgOfklUqJC.JPG
# saving: ../data/mask\colored_mask_images/t002/AWKZYHmepZ.JPG
# saving: ../data/mask\colored_mask_images/t002/AyPUCFEHdl.JPG
# saving: ../data/mask\colored_mask_images/t004/HvWBuYopvg.JPG
# saving: ../data/mask\colored_mask_images/t004/IMEfzVXYDG.JPG
# saving: ../data/mask\colored_mask_images/t004/IPDPLObGot.JPG
# saving: ../data/mask\colored_mask_images/t004/ImWKHwkZLP.jpg
# saving: ../data/mask\colored_mask_images/t004/IrAQtrWqPb.jpg
# saving: ../data/mask\colored_mask_images/t004/KooRzgwBTy.jpg
# saving: ../data/mask\colored_mask_images/t004/MHGOaDZCbV.jpg
# saving: ../data/mask\colored_mask_images/t004/MrzJgLCwXQ.jpg
# saving: ../data/mask\colored_mask_images/t004/MzIRwubLJv.jpg
# saving: ../data/mask\colored_mask_images/t004/NMHHaXjPLW.JPG
# saving: ../data/mask\colored_mask_images/t004/NZesflDnhD.JPG
# saving: ../data/mask\colored_mask_images/t004/NnzPkEXOJI.jpg
# saving: ../data/mask\colored_mask_images/t004/OCIYGKxbXH.jpg
# saving: ../data/mask\colored_mask_images/t004/OKKtfiJEph.JPG
# saving: ../data/mask\colored_mask_images/t004/PxsdqRGBPt.JPG
# saving: ../data/mask\colored_mask_images/t004/QYXkRurBBL.JPG
# saving: ../data/mask\colored_mask_images/t004/SAVdswKblZ.JPG
# saving: ../data/mask\colored_mask_images/t004/TNMlJNQxaz.jpg
# saving: ../data/mask\colored_mask_images/t004/VEmdnrnZaq.jpg
# saving: ../data/mask\colored_mask_images/t004/WdDLexzwWs.jpg
# saving: ../data/mask\colored_mask_images/t004/WtDkexOcPu.JPG
# saving: ../data/mask\colored_mask_images/t004/WubhiUouNb.JPG
# saving: ../data/mask\colored_mask_images/t004/XdJuTkuhjR.jpg
# saving: ../data/mask\colored_mask_images/t004/YrnlzGqgoP.jpg
# saving: ../data/mask\colored_mask_images/t004/aLyJUYVQvW.jpg
# saving: ../data/mask\colored_mask_images/t004/bvLmAVTbCI.JPG
# saving: ../data/mask\colored_mask_images/t004/cOhVFuQqFb.JPG
# saving: ../data/mask\colored_mask_images/t004/dINEzwvtNh.JPG
# saving: ../data/mask\colored_mask_images/t004/dLStUgZiYK.JPG
# saving: ../data/mask\colored_mask_images/t004/jDsPpMVIQh.jpg
# saving: ../data/mask\colored_mask_images/t004/kKVWweSZts.JPG
# saving: ../data/mask\colored_mask_images/t004/koFAOTQqId.jpg
# saving: ../data/mask\colored_mask_images/t004/kqGflQwhSL.jpg
# saving: ../data/mask\colored_mask_images/t004/lViAyETNRK.jpg
# saving: ../data/mask\colored_mask_images/t004/lWaKTGEqNQ.jpg
# saving: ../data/mask\colored_mask_images/t004/myJquAdOaf.JPG
# saving: ../data/mask\colored_mask_images/t004/nEXKYosGOF.JPG
# saving: ../data/mask\colored_mask_images/t004/onJBUEeONU.JPG
# saving: ../data/mask\colored_mask_images/t004/pAeOVOUzVp.JPG
# saving: ../data/mask\colored_mask_images/t004/qATtissSDz.jpg
# saving: ../data/mask\colored_mask_images/t004/tTkLUOXcLP.JPG
# saving: ../data/mask\colored_mask_images/t004/wLqHmKDeHY.JPG
# saving: ../data/mask\colored_mask_images/t004/xmmXsMoazM.JPG
# saving: ../data/mask\colored_mask_images/t004/yQKABaiVBh.JPG
# saving: ../data/mask\colored_mask_images/t004/zUgSLZzQOb.JPG
# saving: ../data/mask\colored_mask_images/t007/mxtsUWgyZP.JPG
# saving: ../data/mask\colored_mask_images/t007/nAbliWXsZs.JPG
# saving: ../data/mask\colored_mask_images/t007/nNjbZAQATr.JPG
# saving: ../data/mask\colored_mask_images/t007/pBRIlcvUCQ.JPG
# saving: ../data/mask\colored_mask_images/t007/tBBfPsgDEy.JPG
# saving: ../data/mask\colored_mask_images/t007/tGosBfkLnc.JPG
# saving: ../data/mask\colored_mask_images/t007/tgwcyZBmCW.JPG
# saving: ../data/mask\colored_mask_images/t007/vOiTTqYJor.JPG
# saving: ../data/mask\colored_mask_images/t007/vUeJgjSgvr.JPG
# saving: ../data/mask\colored_mask_images/t007/vVOgPTtIBk.JPG
# saving: ../data/mask\colored_mask_images/t007/vvijsBqKiM.JPG
# saving: ../data/mask\colored_mask_images/t007/woyemqnJnP.JPG
# saving: ../data/mask\colored_mask_images/t007/zhfCTvDAyO.JPG
# saving: ../data/mask\colored_mask_images/t007/zwhXVThbZj.JPG
# saving: ../data/mask\colored_mask_images/t008/AoWnZBhmzJ.JPG
# saving: ../data/mask\colored_mask_images/t008/HFscFvXgkE.JPG
# saving: ../data/mask\colored_mask_images/t008/HOtErXfaSN.JPG
# saving: ../data/mask\colored_mask_images/t008/HRgunEBVpR.JPG
# saving: ../data/mask\colored_mask_images/t008/JIqNDNaKHD.JPG
# saving: ../data/mask\colored_mask_images/t008/KZYlaPjqgI.JPG
# saving: ../data/mask\colored_mask_images/t008/MLIpSizqjz.JPG
# saving: ../data/mask\colored_mask_images/t008/MUeDEmDTkO.JPG
# saving: ../data/mask\colored_mask_images/t008/OaKjhEHFMX.jpg
# saving: ../data/mask\colored_mask_images/t008/PaXakrkxqN.JPG
# saving: ../data/mask\colored_mask_images/t008/QYYyqViFZB.JPG
# saving: ../data/mask\colored_mask_images/t008/ShZANpaDrS.JPG
# ----------------------------------------------------------------------
# KeyboardInterrupt                    Traceback (most recent call last)
# Cell In[7], line 41
#      39     category_name = coco.loadCats(ann['category_id'])[0]['name']
#      40     color_value = category_color_map.get(category_name, (0, 0, 0))  # 获取 RGB 颜色
# ---> 41     mask += np.dstack([coco.annToMask(ann) * color for color in color_value])
#      42 masked_image_path = os.path.join(mask_dir, f"colored_mask_{image_file}")
#      43 os.makedirs(os.path.dirname(masked_image_path), exist_ok=True)
#
# Cell In[7], line 41, in <listcomp>(.0)
#      39     category_name = coco.loadCats(ann['category_id'])[0]['name']
#      40     color_value = category_color_map.get(category_name, (0, 0, 0))  # 获取 RGB 颜色
# ---> 41     mask += np.dstack([coco.annToMask(ann) * color for color in color_value])
#      42 masked_image_path = os.path.join(mask_dir, f"colored_mask_{image_file}")
#      43 os.makedirs(os.path.dirname(masked_image_path), exist_ok=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycocotools\coco.py:443, in COCO.annToMask(self, ann)
#     438 """
#     439 Convert annotation which can be polygons, uncompressed RLE, or RLE to binary mask.
#     440 :return: binary mask (numpy 2D array)
#     441 """
#     442 rle = self.annToRLE(ann)
# --> 443 m = maskUtils.decode(rle)
#     444 return m
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pycocotools\mask.py:91, in decode(rleObjs)
#      89     return _mask.decode(rleObjs)
#      90 else:
# ---> 91     return _mask.decode([rleObjs])[:,:,0]
#
# KeyboardInterrupt:
